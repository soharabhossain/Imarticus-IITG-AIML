# %% [markdown]
# # Human Face Detection from Images

# %%
import cv2
from IPython.display import Image, display

# %%
class DetectFace:
	def __init__(self, faceCascadePath):
		# load the face detector
		self.faceCascade = cv2.CascadeClassifier(faceCascadePath)

	def detect(self, image, scaleFactor = 1.1, minNeighbors = 5, minSize = (30, 30)):
		# detect faces in the image
		rects = self.faceCascade.detectMultiScale(image,
			scaleFactor = scaleFactor, minNeighbors = minNeighbors,
			minSize = minSize, flags = cv2.CASCADE_SCALE_IMAGE)

		# return the rectangles representing bounding
		# boxes around the faces
		return rects

# %% [markdown]
# # Read an image

# %%
#input_file = 'sundar.png'
input_file = 'group_pic_1.png'

display(Image(filename=input_file))

# %%
# Face detector haar-cascade file for frontal facial images
face = "haarcascade_frontalface_default.xml"

# %%
image = cv2.imread(input_file)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %% [markdown]
# ## Detect Facial regions in the input image

# %%
fd = DetectFace(face)
faceRects = fd.detect(gray, scaleFactor = 1.2, minNeighbors = 5, minSize = (30, 30))

print(" Found {} no. of faces".format(len(faceRects)))
# Out:
#  Found 11 no. of faces

# %%
# Loop over the faces and draw a rectangle around each

# Mark the facial regions on the input image
for (x, y, w, h) in faceRects:
  cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 2)

# %%
cv2.imwrite('outImage.jpg', image)
# Out:
# True

# %%
display(Image(filename='outImage.jpg'))
